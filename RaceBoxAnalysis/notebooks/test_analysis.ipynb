# %%
# ===== CELL 1: Setup =====
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Make plots appear inline
# %matplotlib inline

# Better default plot style
plt.style.use('seaborn-v0_8-darkgrid')

print("✅ Environment ready!")
# Out:
# ✅ Environment ready!

# %%
# ===== CELL 2: Load Data =====
# Put your CSV in the same folder as this notebook
filename = "RaceBoxData\RaceBox Track Sessionon 22-10-2025 14-27(in).csv"

# Skip the metadata rows
df = pd.read_csv(filename, skiprows=12)

print(f"📊 Loaded {len(df):,} data points")
print(f"📏 Columns: {list(df.columns)}")
# Out:
# 📊 Loaded 5,192 data points
# 📏 Columns: ['Record', 'Time', 'Latitude', 'Longitude', 'Altitude', 'Speed', 'GForceX', 'GForceY', 'GForceZ', 'Lap', 'GyroX', 'GyroY', 'GyroZ']
# <>:3: SyntaxWarning: invalid escape sequence '\R'
# <>:3: SyntaxWarning: invalid escape sequence '\R'
# C:\Users\Manu\AppData\Local\Temp\ipykernel_45756\776431206.py:3: SyntaxWarning: invalid escape sequence '\R'
#   filename = "RaceBoxData\RaceBox Track Sessionon 22-10-2025 14-27(in).csv"

# %%
# ===== CELL 3: Inspect Data =====
# First 5 rows
df.head()
# Out:
#    Record                      Time   Latitude  Longitude  Altitude  Speed  \
# 0       1  2025-10-22T19:27:56.000Z  36.140590 -86.733312     550.3  15.69
# 1       2  2025-10-22T19:27:56.040Z  36.140591 -86.733310     550.3  15.86
# 2       3  2025-10-22T19:27:56.080Z  36.140593 -86.733308     550.3  15.86
# 3       4  2025-10-22T19:27:56.120Z  36.140595 -86.733306     550.4  15.73
# 4       5  2025-10-22T19:27:56.160Z  36.140597 -86.733304     550.4  15.66
#
#    GForceX  GForceY  GForceZ  Lap  GyroX  GyroY  GyroZ
# 0   -0.286    0.238   -0.228    0   0.13  -0.44   9.17
# 1   -0.247    0.275   -0.156    0   0.50  -0.59  12.27
# 2   -0.183    0.312    0.064    0   0.78   0.00  15.26
# 3   -0.122    0.357    0.373    0   0.65   0.88  17.84
# 4   -0.083    0.376    0.635    0   0.40   1.57  19.90

# %%
# ===== CELL 4: Data Info =====
# See data types and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5192 entries, 0 to 5191
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Record     5192 non-null   int64
#  1   Time       5192 non-null   object
#  2   Latitude   5192 non-null   float64
#  3   Longitude  5192 non-null   float64
#  4   Altitude   5192 non-null   float64
#  5   Speed      5192 non-null   float64
#  6   GForceX    5192 non-null   float64
#  7   GForceY    5192 non-null   float64
#  8   GForceZ    5192 non-null   float64
#  9   Lap        5192 non-null   int64
#  10  GyroX      5192 non-null   float64
#  11  GyroY      5192 non-null   float64
#  12  GyroZ      5192 non-null   float64
# dtypes: float64(10), int64(2), object(1)
# memory usage: 527.4+ KB

# %%
# ===== CELL 5: Basic Stats =====
# Summary statistics
df[['Speed', 'GForceX', 'GForceY', 'Lap']].describe()
# Out:
#              Speed      GForceX      GForceY     Lap
# count  5192.000000  5192.000000  5192.000000  5192.0
# mean     20.232625    -0.451136    -0.314711     0.0
# std       3.573055     0.319210     0.630342     0.0
# min      12.690000    -1.135000    -1.295000     0.0
# 25%      17.930000    -0.735250    -0.832000     0.0
# 50%      19.725000    -0.427000    -0.528500     0.0
# 75%      22.140000    -0.183750     0.158000     0.0
# max      35.580000     0.465000     1.160000     0.0

# %%
# ===== CELL 6: Filter One Lap =====
lap_num = 0
lap_data = df[df['Lap'] == lap_num].copy()
print(f"Lap {lap_num} has {len(lap_data)} data points")
# Out:
# Lap 0 has 5192 data points

# %%
# ===== CELL 7: First Plot =====
plt.figure(figsize=(12, 6))
plt.plot(lap_data['Speed'], linewidth=2)
plt.xlabel('Data Point')
plt.ylabel('Speed (km/h)')
plt.title(f'Lap {lap_num} - Speed Profile')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# "\nracebox-analysis/\n│\n├── venv/                          # Virtual environment (don't commit)\n├── data/                          # Put your CSV files here\n│   └── 10 23102024....csv\n├── notebooks/                     # Your Jupyter notebooks\n│   ├── 01_exploration.ipynb\n│   ├── 02_lap_analysis.ipynb\n│   └── 03_visualizations.ipynb\n├── scripts/                       # Production Python scripts\n│   └── analyze.py\n└── README.md                      # Notes for yourself \n"
